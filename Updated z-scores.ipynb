# %%
import sys
import matplotlib.pyplot as plt
sys.path.append('/Users/adriennekirk/Desktop/Flash Droughts/')  
from FlashDroughts import KDEhistogram 
from FlashDroughts import DroughtDetection
# drought2 = DroughtDetection(lat=43.66, lon=-70.26, rolling_column = 'precip',weeks =2, residual_column= 'pet')
drought4 = DroughtDetection(lat=43.66, lon=-70.26, rolling_column = 'precip',weeks = 4, residual_column=None)

# %%
# drought2.two_week_spei_plot('pet 2 rolling', ['pearson'], 2002, 2024)
# drought2.four_week_spei_plot('pet 2 rolling', ['pearson'], 2002, 2024)
drought4.two_week_spei_plot('precip 4 rolling', ['pearson'], 2002, 2024)
drought4.four_week_spei_plot('precip 4 rolling', ['pearson'], 2002, 2024)

# %%
drought4.two_week_onset('precip 4 rolling',['pearson'])

# %%
drought4.residual_dataframe()['2015':'2016'].head(50)
