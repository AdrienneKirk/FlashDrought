# %%
import requests
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import scipy.stats as stats
import seaborn as sns
import matplotlib.dates as mdates
from datetime import datetime
import matplotlib.gridspec as gridspec
import scipy.stats
from scipy.stats import gaussian_kde

# %%
import sys
sys.path.append('/Users/adriennekirk/Desktop/Flash Droughts/')  
from FlashDroughts import KDEhistogram 
from FlashDroughts import DroughtDetection

kde = KDEhistogram(
    sdate='2002-03-01',
    edate='2024-05-31',
    lat=43.66,
    lon=-70.26
)
# print(kde.weekly('spring')['vwc'].groupby(kde.weekly('spring').index.year).count())
# spring = kde.weekly('spring')
# print(spring)
# kde.kde_histogram()
# spring = kde.individual_dataframes()[0]
# summer = kde.individual_dataframes()[1]
# fall = kde.individual_dataframes()[2]
# spring_residuals = kde._linear_regression('spring', 'vwc')
# spring_residuals_histogram = kde.weekly_plot('spring', residuals=['vwc', 'pet'])
# print(spring_residuals_histogram)
kde.kde_histogram(residuals = ['vwc', 'pet'])
# Out:
# /Users/adriennekirk/Desktop/Flash Droughts/FlashDroughts.py:77: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   combined = combined.groupby('year', group_keys=False).apply(drop_first_and_last_week)
# /Users/adriennekirk/Desktop/Flash Droughts/FlashDroughts.py:77: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   combined = combined.groupby('year', group_keys=False).apply(drop_first_and_last_week)
# ...

# %%
# import sys
# sys.path.append('/Users/adriennekirk/Desktop/Flash Droughts/')  
# from FlashDroughts import KDEhistogram 
# from FlashDroughts import DroughtDetection

# drought = DroughtDetection(sdate='2020-03-01',
#     edate='2024-05-31',
#     lat=43.66,
#     lon=-70.26)

# # drought2 = KDEhistogram(sdate='2024-03-01',
# #     edate='2024-05-31',
# #     lat=43.66,
# #     lon=-70.26)
# # # drought2.spring_weekly_plot()
# # spring = drought2.individual_dataframes()[0]
# # vwc = np.array(spring['vwc'])
# # print(vwc)
# # filt = ~np.isnan(vwc)
# # vwc = vwc[filt]
# # date = np.array(spring.index[filt])
# # timediff = np.diff(date).astype('timedelta64[D]').astype(float)
# # rate = np.diff(vwc)/timediff
# # plt.plot(date, vwc)

# drought.pet_curve('spring')
# drought.pet_curve('summer')
# drought.pet_curve('fall')
# # Example thresholds (adjust as needed)
# p_vwc = [70, 55, 50, 40, 35, 30]
# p_pet = [70, 75, 80, 85, 90, 95]
# # VWC
# drought.categorize(*p_vwc, 'spring', 'vwc')
# drought.categorize(*p_vwc, 'summer', 'vwc')
# drought.categorize(*p_vwc, 'fall', 'vwc')

# # PET
# drought.categorize(*p_pet, 'spring', 'pet')
# drought.categorize(*p_pet, 'summer', 'pet')
# drought.categorize(*p_pet, 'fall', 'pet')

# # Normalized PET
# drought.categorize(*p_pet, 'spring', 'Norm PET Val')
# drought.categorize(*p_pet, 'summer', 'Norm PET Val')
# drought.categorize(*p_pet, 'fall', 'Norm PET Val')

# # drought.individual_plot('spring','vwc')


# # # # VWC
# # drought.individual_plot('spring', 'vwc')
# # # drought.individual_plot('summer', 'vwc')
# # # drought.individual_plot('fall', 'vwc')

# # # # PET
# # drought.individual_plot('spring', 'pet')
# # # drought.individual_plot('summer', 'pet')
# # # drought.individual_plot('fall', 'pet')

# # # # Normalized PET
# # drought.individual_plot('spring', 'Norm PET Val')
# # drought.individual_plot('summer', 'Norm PET Val')
# # drought.individual_plot('fall', 'Norm PET Val')

# drought.full_plot()

# %%
# drought.categorize(*p_vwc, 'spring', 'vwc').head(28)

# %%
# drought.categorize(*p_vwc, 'summer', 'vwc').head(28)

# %%
# import sys
# sys.path.append('/Users/adriennekirk/Desktop/Flash Droughts/')  
# from FlashDroughts import KDEhistogram 
# from FlashDroughts import DroughtDetection

# drought = DroughtDetection(sdate='2020-03-01',
#     edate='2024-05-31',
#     lat=43.66,
#     lon=-70.26)

# # drought2 = KDEhistogram(sdate='2024-03-01',
# #     edate='2024-05-31',
# #     lat=43.66,
# #     lon=-70.26)
# # # drought2.spring_weekly_plot()
# # spring = drought2.individual_dataframes()[0]
# # vwc = np.array(spring['vwc'])
# # print(vwc)
# # filt = ~np.isnan(vwc)
# # vwc = vwc[filt]
# # date = np.array(spring.index[filt])
# # timediff = np.diff(date).astype('timedelta64[D]').astype(float)
# # rate = np.diff(vwc)/timediff
# # plt.plot(date, vwc)

# drought.pet_curve('spring')
# drought.pet_curve('summer')
# drought.pet_curve('fall')
# # Example thresholds (adjust as needed)
# p_vwc = [70, 55, 50, 40, 35, 30]
# p_pet = [70, 75, 80, 85, 90, 95]
# # VWC
# drought.categorize(*p_vwc, 'spring', 'vwc')
# drought.categorize(*p_vwc, 'summer', 'vwc')
# drought.categorize(*p_vwc, 'fall', 'vwc')

# # PET
# drought.categorize(*p_pet, 'spring', 'pet')
# drought.categorize(*p_pet, 'summer', 'pet')
# drought.categorize(*p_pet, 'fall', 'pet')

# # Normalized PET
# drought.categorize(*p_pet, 'spring', 'Norm PET Val')
# drought.categorize(*p_pet, 'summer', 'Norm PET Val')
# drought.categorize(*p_pet, 'fall', 'Norm PET Val')

# drought.full_plot()


# # # # VWC
# # drought.individual_plot('spring', 'vwc')
# # # drought.individual_plot('summer', 'vwc')
# # # drought.individual_plot('fall', 'vwc')

# # # # PET
# # drought.individual_plot('spring', 'pet')
# # # drought.individual_plot('summer', 'pet')
# # # drought.individual_plot('fall', 'pet')

# # # # Normalized PET
# # drought.individual_plot('spring', 'Norm PET Val')
# # # drought.individual_plot('summer', 'Norm PET Val')
# # # drought.individual_plot('fall', 'Norm PET Val')

# %%
# plt.scatter(spring.index, spring['pet'])

# %%
# import sys
# sys.path.append('/Users/adriennekirk/Desktop/Flash Droughts/')  
# from FlashDroughts import KDEhistogram
# from scipy.stats import linregress 

# kde = KDEhistogram(
#     sdate='2024-03-01',
#     edate='2024-10-31',
#     lat=43.66,
#     lon=-70.26
# )
# spring = kde.weekly('spring')
# summer = kde.weekly('summer')
# fall = kde.weekly('fall')
# fig, axs = plt.subplots(3,1, figsize=(12,8))

# axs[0].scatter(spring.index, spring['pet'])
# axs[1].scatter(summer.index, summer['pet'], color = 'darkorange')
# axs[2].scatter(fall.index, fall['pet'], color = 'm')

# axs[0].set_xlabel('weeks')
# axs[0].set_ylabel('weekly PET Val')
# axs[1].set_xlabel('weeks')
# axs[1].set_ylabel('weekly PET Val')
# axs[2].set_xlabel('weeks')
# axs[2].set_ylabel('weekly PET Val')

# axs[0].set_title('Spring')
# axs[1].set_title('Summer')
# axs[2].set_title('Fall')

# sp_x = spring.index.map(lambda date: date.toordinal())
# sp_slope, sp_intercept, sp_r_value, sp_p_value, sp_std_err = linregress(sp_x, spring['pet'])
# sp_y_fit = sp_slope * sp_x + sp_intercept
# axs[0].plot(spring.index, sp_y_fit, color='red', label=f'Fit: y={sp_slope:.2f}x+{sp_intercept:.2f}')
# sp_equation = f'y = {sp_slope:.2f}x + {sp_intercept:.2f}'
# sp_r_squared = f'R^2 = {sp_r_value**2:.2f}'
# print(f' Spring R^2 : {sp_r_value}')
# print(f' Spring p_value : {sp_p_value}')
# axs[0].text(spring.index[0], max(sp_y_fit)*0.9, sp_equation, fontsize=10, color='red')
# axs[0].text(spring.index[0], max(sp_y_fit)*0.8,sp_r_squared , fontsize=10, color='red')

# sum_x = summer.index.map(lambda date: date.toordinal())
# sum_slope, sum_intercept, sum_r_value, sum_p_value, sum_std_err = linregress(sum_x, summer['pet'])
# sum_y_fit = sum_slope * sum_x + sum_intercept
# axs[1].plot(summer.index, sum_y_fit, color='red', label=f'Fit: y={sum_slope:.2f}x+{sum_intercept:.2f}')
# sum_equation = f'y = {sum_slope:.2f}x + {sum_intercept:.2f}'
# sum_r_squared = f'R^2 = {sum_r_value**2:.2f}'
# print(f' Summer R^2 : {sum_r_value}')
# print(f' Summer p_value : {sum_p_value}')
# axs[1].text(summer.index[0], max(sum_y_fit)*0.9, sum_equation, fontsize=10, color='red')
# axs[1].text(summer.index[0], max(sum_y_fit)*0.85,sum_r_squared , fontsize=10, color='red')

# fall_x = fall.index.map(lambda date: date.toordinal())
# fall_slope, fall_intercept, fall_r_value, fall_p_value, fall_std_err = linregress(fall_x, fall['pet'])
# fall_y_fit = fall_slope * fall_x + fall_intercept
# axs[2].plot(fall.index, fall_y_fit, color='red', label=f'Fit: y={fall_slope:.2f}x+{fall_intercept:.2f}')
# fall_equation = f'y = {fall_slope:.2f}x + {fall_intercept:.2f}'
# fall_r_squared = f'R^2 = {fall_r_value**2:.2f}'
# print(f' Fall R^2 : {fall_r_value}')
# print(f' Fall p_value : {fall_p_value}')
# axs[2].text(fall.index[0], max(fall_y_fit)*0.8, fall_equation, fontsize=10, color='red')
# axs[2].text(fall.index[0], max(fall_y_fit)*0.75,fall_r_squared , fontsize=10, color='red')

# plt.suptitle('2024 Ithaca PET Weekly')
# plt.tight_layout()
# plt.show()

# %%
# sp_residuals = spring['pet'] - sp_y_fit
# sum_residuals = summer['pet'] - sum_y_fit
# fall_residuals = fall['pet'] - fall_y_fit

# fig, axs = plt.subplots(3,1, figsize=(12,8))
# axs[0].plot(spring.index, sp_residuals)
# axs[1].plot(summer.index, sum_residuals, color = 'darkorange')
# axs[2].plot(fall.index, fall_residuals, color = 'm')
# axs[0].scatter(spring.index, sp_residuals)
# axs[1].scatter(summer.index, sum_residuals, color = 'darkorange')
# axs[2].scatter(fall.index, fall_residuals, color = 'm')

# axs[0].set_xlabel('weeks')
# axs[0].set_ylabel('Residual PET Val')
# axs[1].set_xlabel('weeks')
# axs[1].set_ylabel('Residual PET Val')
# axs[2].set_xlabel('weeks')
# axs[2].set_ylabel('Residual PET Val')

# axs[0].set_title('Spring')
# axs[1].set_title('Summer')
# axs[2].set_title('Fall')

# plt.suptitle('2024 Ithaca PET Weekly Residuals')
# plt.tight_layout()
# plt.show()

# %%
# spring = kde.individual_dataframes('spring')
# summer = kde.individual_dataframes('summer')
# fall = kde.individual_dataframes('fall')

# fig, axs = plt.subplots(3,1, figsize=(10, 8))
# axs[0].scatter(spring.index, spring['pet'])
# axs[1].scatter(summer.index, summer['pet'])
# axs[2].scatter(fall.index, fall['pet'])

# axs[0].set_xlabel('days')
# axs[0].set_ylabel('daily PET Val')
# axs[1].set_xlabel('days')
# axs[1].set_ylabel('daily PET Val')
# axs[2].set_xlabel('days')
# axs[2].set_ylabel('daily PET Val')

# axs[0].set_title('Spring')
# axs[1].set_title('Summer')
# axs[2].set_title('Fall')

# sp_x = spring.index
# sp_slope, sp_intercept, sp_r_value, sp_p_value, sp_std_err = linregress(sp_x, spring['pet'])
# sp_y_fit = sp_slope * sp_x + sp_intercept
# axs[0].plot(spring.index, sp_y_fit, color='red', label=f'Fit: y={sp_slope:.2f}x+{sp_intercept:.2f}')
# sp_equation = f'y = {sp_slope:.2f}x + {sp_intercept:.2f}'
# sp_r_squared = f'R^2 = {sp_r_value**2:.2f}'
# print(f' Spring R^2 : {sp_r_value}')
# print(f' Spring p_value : {sp_p_value}')
# axs[0].text(spring.index[0], max(sp_y_fit)*0.95, sp_equation, fontsize=10, color='red')
# axs[0].text(spring.index[0], max(sp_y_fit)*0.80,sp_r_squared , fontsize=10, color='red')

# sum_x = summer.index
# sum_slope, sum_intercept, sum_r_value, sum_p_value, sum_std_err = linregress(sum_x, summer['pet'])
# sum_y_fit = sum_slope * sum_x + sum_intercept
# axs[1].plot(summer.index, sum_y_fit, color='red', label=f'Fit: y={sum_slope:.2f}x+{sum_intercept:.2f}')
# sum_equation = f'y = {sum_slope:.2f}x + {sum_intercept:.2f}'
# sum_r_squared = f'R^2 = {sum_r_value**2:.2f}'
# print(f' Summer R^2 : {sum_r_value}')
# print(f' Summer p_value : {sum_p_value}')
# axs[1].text(summer.index[-11], max(sum_y_fit)*1.25, sum_equation, fontsize=10, color='red')
# axs[1].text(summer.index[-11], max(sum_y_fit)*1.10,sum_r_squared , fontsize=10, color='red')

# fall_x = fall.index
# fall_slope, fall_intercept, fall_r_value, fall_p_value, fall_std_err = linregress(fall_x, fall['pet'])
# fall_y_fit = fall_slope * fall_x + fall_intercept
# axs[2].plot(fall.index, fall_y_fit, color='red', label=f'Fit: y={fall_slope:.2f}x+{fall_intercept:.2f}')
# fall_equation = f'y = {fall_slope:.2f}x + {fall_intercept:.2f}'
# fall_r_squared = f'R^2 = {fall_r_value**2:.2f}'
# print(f' Fall R^2 : {fall_r_value}')
# print(f' Fall p_value : {fall_p_value}')
# axs[2].text(fall.index[-10], max(fall_y_fit)*1, fall_equation, fontsize=10, color='red')
# axs[2].text(fall.index[-10], max(fall_y_fit)*0.90,fall_r_squared , fontsize=10, color='red')

# plt.suptitle('2024 Ithaca PET Daily')
# plt.tight_layout()
# plt.show()

# %%
# sp_residuals = spring['pet'] - sp_y_fit
# sum_residuals = summer['pet'] - sum_y_fit
# fall_residuals = fall['pet'] - fall_y_fit

# fig, axs = plt.subplots(3,1, figsize=(12,8))
# axs[0].plot(spring.index, sp_residuals)
# axs[1].plot(summer.index, sum_residuals, color = 'darkorange')
# axs[2].plot(fall.index, fall_residuals, color = 'm')
# axs[0].scatter(spring.index, sp_residuals)
# axs[1].scatter(summer.index, sum_residuals, color = 'darkorange')
# axs[2].scatter(fall.index, fall_residuals, color = 'm')

# axs[0].set_xlabel('days')
# axs[0].set_ylabel('Residual PET Val')
# axs[1].set_xlabel('days')
# axs[1].set_ylabel('Residual PET Val')
# axs[2].set_xlabel('days')
# axs[2].set_ylabel('Residual PET Val')

# axs[0].set_title('Spring')
# axs[1].set_title('Summer')
# axs[2].set_title('Fall')

# plt.suptitle('2024 Ithaca PET Daily Residuals')
# plt.tight_layout()
# plt.show()

# %%
# ##### VWCCCCCCC


# import sys
# sys.path.append('/Users/adriennekirk/Desktop/Flash Droughts/')  
# from FlashDroughts import KDEhistogram
# from scipy.stats import linregress 

# kde = KDEhistogram(
#     sdate='2024-03-01',
#     edate='2024-10-31',
#     lat=43.66,
#     lon=-70.26
# )
# spring = kde.weekly('spring')
# summer = kde.weekly('summer')
# fall = kde.weekly('fall')
# fig, axs = plt.subplots(3,1, figsize=(12,8))

# axs[0].scatter(spring.index, spring['vwc'])
# axs[1].scatter(summer.index, summer['vwc'], color = 'darkorange')
# axs[2].scatter(fall.index, fall['vwc'], color = 'm')

# axs[0].set_xlabel('weeks')
# axs[0].set_ylabel('weekly VWC Val')
# axs[1].set_xlabel('weeks')
# axs[1].set_ylabel('weekly VWC Val')
# axs[2].set_xlabel('weeks')
# axs[2].set_ylabel('weekly VWC Val')

# axs[0].set_title('Spring')
# axs[1].set_title('Summer')
# axs[2].set_title('Fall')

# sp_x = spring.index.map(lambda date: date.toordinal())
# sp_slope, sp_intercept, sp_r_value, sp_p_value, sp_std_err = linregress(sp_x, spring['vwc'])
# sp_y_fit = sp_slope * sp_x + sp_intercept
# axs[0].plot(spring.index, sp_y_fit, color='red', label=f'Fit: y={sp_slope:.2f}x+{sp_intercept:.2f}')
# sp_equation = f'y = {sp_slope:.2f}x + {sp_intercept:.2f}'
# sp_r_squared = f'R^2 = {sp_r_value**2:.2f}'
# print(f' Spring R^2 : {sp_r_value}')
# print(f' Spring p_value : {sp_p_value}')
# axs[0].text(spring.index[0], max(sp_y_fit)*0.7, sp_equation, fontsize=10, color='red')
# axs[0].text(spring.index[0], max(sp_y_fit)*0.6,sp_r_squared , fontsize=10, color='red')

# sum_x = summer.index.map(lambda date: date.toordinal())
# sum_slope, sum_intercept, sum_r_value, sum_p_value, sum_std_err = linregress(sum_x, summer['vwc'])
# sum_y_fit = sum_slope * sum_x + sum_intercept
# axs[1].plot(summer.index, sum_y_fit, color='red', label=f'Fit: y={sum_slope:.2f}x+{sum_intercept:.2f}')
# sum_equation = f'y = {sum_slope:.2f}x + {sum_intercept:.2f}'
# sum_r_squared = f'R^2 = {sum_r_value**2:.2f}'
# print(f' Summer R^2 : {sum_r_value}')
# print(f' Summer p_value : {sum_p_value}')
# axs[1].text(summer.index[0], max(sum_y_fit)*0.95, sum_equation, fontsize=10, color='red')
# axs[1].text(summer.index[0], max(sum_y_fit)*0.85,sum_r_squared , fontsize=10, color='red')

# fall_x = fall.index.map(lambda date: date.toordinal())
# fall_slope, fall_intercept, fall_r_value, fall_p_value, fall_std_err = linregress(fall_x, fall['vwc'])
# fall_y_fit = fall_slope * fall_x + fall_intercept
# axs[2].plot(fall.index, fall_y_fit, color='red', label=f'Fit: y={fall_slope:.2f}x+{fall_intercept:.2f}')
# fall_equation = f'y = {fall_slope:.2f}x + {fall_intercept:.2f}'
# fall_r_squared = f'R^2 = {fall_r_value**2:.2f}'
# print(f' Fall R^2 : {fall_r_value}')
# print(f' Fall p_value : {fall_p_value}')
# axs[2].text(fall.index[0], max(fall_y_fit)*0.85, fall_equation, fontsize=10, color='red')
# axs[2].text(fall.index[0], max(fall_y_fit)*0.75,fall_r_squared , fontsize=10, color='red')

# plt.suptitle('2024 Ithaca VWC Weekly')
# plt.tight_layout()
# plt.show()

# %%
# sp_residuals = spring['vwc'] - sp_y_fit
# sum_residuals = summer['vwc'] - sum_y_fit
# fall_residuals = fall['vwc'] - fall_y_fit

# fig, axs = plt.subplots(3,1, figsize=(12,8))
# axs[0].plot(spring.index, sp_residuals)
# axs[1].plot(summer.index, sum_residuals, color = 'darkorange')
# axs[2].plot(fall.index, fall_residuals, color = 'm')
# axs[0].scatter(spring.index, sp_residuals)
# axs[1].scatter(summer.index, sum_residuals, color = 'darkorange')
# axs[2].scatter(fall.index, fall_residuals, color = 'm')

# axs[0].set_xlabel('weeks')
# axs[0].set_ylabel('Residual VWC Val')
# # axs[1].set_xlabel('weeks')
# axs[1].set_ylabel('Residual VWC Val')
# axs[2].set_xlabel('weeks')
# axs[2].set_ylabel('Residual VWC Val')

# axs[0].set_title('Spring')
# axs[1].set_title('Summer')
# axs[2].set_title('Fall')

# plt.suptitle('2024 Ithaca VWC Weekly Residuals')
# plt.tight_layout()
# plt.show()

# %%
# spring = kde.individual_dataframes('spring')
# summer = kde.individual_dataframes('summer')
# fall = kde.individual_dataframes('fall')
# print(spring['vwc'])

# fig, axs = plt.subplots(3,1, figsize=(10, 8))
# axs[0].scatter(spring.index, spring['vwc'])
# axs[1].scatter(summer.index, summer['vwc'])
# axs[2].scatter(fall.index, fall['vwc'])

# axs[0].set_xlabel('days')
# axs[0].set_ylabel('daily VWC Val')
# axs[1].set_xlabel('days')
# axs[1].set_ylabel('daily VWC Val')
# axs[2].set_xlabel('days')
# axs[2].set_ylabel('daily VWC Val')

# axs[0].set_title('Spring')
# axs[1].set_title('Summer')
# axs[2].set_title('Fall')

# # sp_x = spring.index
# # sp_slope, sp_intercept, sp_r_value, sp_p_value, sp_std_err = linregress(sp_x, spring['vwc'])
# # sp_y_fit = sp_slope * sp_x + sp_intercept
# # axs[0].plot(spring.index, sp_y_fit, color='red', label=f'Fit: y={sp_slope:.2f}x+{sp_intercept:.2f}')
# # sp_equation = f'y = {sp_slope:.2f}x + {sp_intercept:.2f}'
# # sp_r_squared = f'R^2 = {sp_r_value**2:.2f}'
# # print(f' Spring R^2 : {sp_r_value}')
# # print(f' Spring p_value : {sp_p_value}')
# # axs[0].text(spring.index[0], max(sp_y_fit)*0.95, sp_equation, fontsize=10, color='red')
# # axs[0].text(spring.index[0], max(sp_y_fit)*0.80,sp_r_squared , fontsize=10, color='red')

# # sum_x = summer.index
# # sum_slope, sum_intercept, sum_r_value, sum_p_value, sum_std_err = linregress(sum_x, summer['vwc'])
# # sum_y_fit = sum_slope * sum_x + sum_intercept
# # axs[1].plot(summer.index, sum_y_fit, color='red', label=f'Fit: y={sum_slope:.2f}x+{sum_intercept:.2f}')
# # sum_equation = f'y = {sum_slope:.2f}x + {sum_intercept:.2f}'
# # sum_r_squared = f'R^2 = {sum_r_value**2:.2f}'
# # print(f' Summer R^2 : {sum_r_value}')
# # print(f' Summer p_value : {sum_p_value}')
# # axs[1].text(summer.index[-11], max(sum_y_fit)*1.25, sum_equation, fontsize=10, color='red')
# # axs[1].text(summer.index[-11], max(sum_y_fit)*1.10,sum_r_squared , fontsize=10, color='red')

# # fall_x = fall.index
# # fall_slope, fall_intercept, fall_r_value, fall_p_value, fall_std_err = linregress(fall_x, fall['vwc'])
# # fall_y_fit = fall_slope * fall_x + fall_intercept
# # axs[2].plot(fall.index, fall_y_fit, color='red', label=f'Fit: y={fall_slope:.2f}x+{fall_intercept:.2f}')
# # fall_equation = f'y = {fall_slope:.2f}x + {fall_intercept:.2f}'
# # fall_r_squared = f'R^2 = {fall_r_value**2:.2f}'
# # print(f' Fall R^2 : {fall_r_value}')
# # print(f' Fall p_value : {fall_p_value}')
# # axs[2].text(fall.index[-10], max(fall_y_fit)*1, fall_equation, fontsize=10, color='red')
# # axs[2].text(fall.index[-10], max(fall_y_fit)*0.90,fall_r_squared , fontsize=10, color='red')

# plt.suptitle('2024 Ithaca VWC Daily')
# plt.tight_layout()
# plt.show()

# %%
import sys
sys.path.append('/Users/adriennekirk/Desktop/Flash Droughts/')  
from FlashDroughts import KDEhistogram 
from FlashDroughts import DroughtDetection

drought = DroughtDetection(sdate='2020-03-01',
    edate='2024-05-31',
    lat=43.66,
    lon=-70.26)
seasons = ['spring', 'summer', 'fall']
columns = ['vwc','pet']
season_dfs = {}
for season in seasons:
    vwc = drought._season(season, residual_column='vwc')
    pet = drought.norm_curve(season, 'pet Residuals')
    df = pd.concat([vwc, pet], axis =1)
    df = df.loc[:, ~df.columns.duplicated()]
    season_dfs[season] = df
spring = season_dfs['spring']
summer = season_dfs['summer']
fall = season_dfs['fall']

drought.full_plot()
# Out:
# /Users/adriennekirk/Desktop/Flash Droughts/FlashDroughts.py:77: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   combined = combined.groupby('year', group_keys=False).apply(drop_first_and_last_week)
# /Users/adriennekirk/Desktop/Flash Droughts/FlashDroughts.py:77: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   combined = combined.groupby('year', group_keys=False).apply(drop_first_and_last_week)
# ...
