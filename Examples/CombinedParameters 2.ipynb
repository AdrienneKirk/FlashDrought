# %%
import sys
import matplotlib.pyplot as plt
import pandas as pd
sys.path.append('/Users/adriennekirk/Desktop/Flash Droughts/')  
from FlashDroughts import KDEhistogram,DroughtDetection

# pet1 = DroughtDetection(lat=43.66, lon=-70.26, rolling_column = 'pet', residual_column='pet', weeks = 1)
pet2 = DroughtDetection(lat=43.66, lon=-70.26, rolling_column = 'pet', residual_column='pet', weeks = 2)
pet4 = DroughtDetection(lat=43.66, lon=-70.26, rolling_column = 'pet', residual_column='pet', weeks = 4)

vwc = DroughtDetection(lat=43.66, lon=-70.26, rolling_column = 'vwc', residual_column=None, weeks = 1)

# precip1 = DroughtDetection(lat=43.66, lon=-70.26, rolling_column = 'precip', residual_column=None, weeks = 1)
precip2 = DroughtDetection(lat=43.66, lon=-70.26, rolling_column = 'precip', residual_column=None, weeks = 2)
precip4 = DroughtDetection(lat=43.66, lon=-70.26, rolling_column = 'precip', residual_column=None, weeks = 4)

# %% [markdown]
# PET1 : rolling 1 (residuals)
# PET2: rolling 2 (residuals)
# PET4: rolling 4 (residuals)
# VWC: always rolling 1
# PRECIP1: rolling 1
# PRECIP2: rolling 2
# PRECIP4: rolling 4

# %% [markdown]
# PET1 Residuals Graphs:
# - Total years: 2002 - 2024
#     - 2cat/2wks and 2cat/4wks
# - 2016
#     -  2cat/2wks and 2cat/4wks

# %%
# pet1.two_week_spei_plot('pet 1 rolling Residuals',['pearson'],2002, 2024)
# # pet1.four_week_spei_plot('pet 1 rolling Residuals',['gamma', 'normal', 'pearson'],2002, 2024)
# pet1.two_week_spei_plot('pet 1 rolling Residuals',['pearson'],2016, 2017)
# # pet1.four_week_spei_plot('pet 1 rolling Residuals',['gamma', 'normal', 'pearson'],2016, 2017)
# pet1.two_week_spei_plot('pet 1 rolling Residuals',['pearson'],2002, 2024, z_score = True)
# pet1.two_week_spei_plot('pet 1 rolling Residuals',['pearson'],2016, 2017, z_score = True)

# %% [markdown]
# PET1 Residuals Combined Onsets
# - 2cat/2wk and 2cat/4wk

# %%
pet1_two_wk = pet1.display_two_wk_onsets('pet 1 rolling Residuals',['gamma', 'normal', 'pearson'])
pet1_four_wk = pet1.display_four_wk_onsets('pet 1 rolling Residuals',['gamma', 'normal', 'pearson'])

# %% [markdown]
# PET2 Residuals Graphs:
# - Total years: 2002 - 2024
#     - 2cat/2wks and 2cat/4wks
# - 2016
#     -  2cat/2wks and 2cat/4wks

# %%
pet2.two_week_spei_plot('pet 2 rolling Residuals',['pearson'],2002, 2024)
pet2.four_week_spei_plot('pet 2 rolling Residuals',['pearson'],2002, 2024)
pet2.two_week_spei_plot('pet 2 rolling Residuals',['pearson'],2002, 2024, z_score = True)
pet2.four_week_spei_plot('pet 2 rolling Residuals',['pearson'],2002, 2024,  z_score = True)
pet2.two_week_spei_plot('pet 2 rolling Residuals',['pearson'],2016, 2017)
pet2.four_week_spei_plot('pet 2 rolling Residuals',['pearson'],2016, 2017)
pet2.two_week_spei_plot('pet 2 rolling Residuals',['pearson'],2016, 2017, z_score = True)
pet2.four_week_spei_plot('pet 2 rolling Residuals',['pearson'],2016, 2017,  z_score = True)

# %% [markdown]
# PET1 Residuals Combined Onsets
# - 2cat/2wk and 2cat/4wk

# %%
pet2_two_wk = pet2.display_two_wk_onsets('pet 2 rolling Residuals',['gamma', 'normal', 'pearson'])
pet2_four_wk = pet2.display_four_wk_onsets('pet 2 rolling Residuals',['gamma', 'normal', 'pearson'])

# %% [markdown]
# PET4 Residuals Graphs:
# - Total years: 2002 - 2024
#     - 2cat/2wks and 2cat/4wks
# - 2016
#     -  2cat/2wks and 2cat/4wks

# %%
pet4.two_week_spei_plot('pet 4 rolling Residuals',['gamma', 'normal', 'pearson'],2002, 2024)
pet4.four_week_spei_plot('pet 4 rolling Residuals',['gamma', 'normal', 'pearson'],2002, 2024)
pet4.two_week_spei_plot('pet 4 rolling Residuals',['gamma', 'normal', 'pearson'],2016, 2017)
pet4.four_week_spei_plot('pet 4 rolling Residuals',['gamma', 'normal', 'pearson'],2016, 2017)

# %% [markdown]
# PET2 Residuals Combined Onsets
# - 2cat/2wk and 2cat/4wk

# %%
pet4_two_wk = pet4.display_two_wk_onsets('pet 4 rolling Residuals',['gamma', 'normal', 'pearson'])
pet4_four_wk = pet4.display_four_wk_onsets('pet 4 rolling Residuals',['gamma', 'normal', 'pearson'])

# %% [markdown]
# VWC Graphs:
# - Total years: 2002 - 2024
#     - 2cat/2wks and 2cat/4wks
# - 2016
#     -  2cat/2wks and 2cat/4wks

# %%
vwc.two_week_spei_plot('vwc 1 rolling',['gamma','normal'],2002, 2024)
vwc.four_week_spei_plot('vwc 1 rolling',['normal'],2002, 2024)
vwc.two_week_spei_plot('vwc 1 rolling',['normal'],2004, 2008)
vwc.four_week_spei_plot('vwc 1 rolling',['normal'],2004, 2008)

# %% [markdown]
# VWC Combined Onsets
# - 2cat/2wk and 2cat/4wk

# %%
vwc_two_wk = vwc.display_two_wk_onsets('vwc 1 rolling',['normal'])
vwc_four_wk = vwc.display_four_wk_onsets('vwc 1 rolling',['normal'])

# %% [markdown]
# Precip1 Graphs:
# - Total years: 2002 - 2024
#     - 2cat/2wks and 2cat/4wks
# - 2016
#     -  2cat/2wks and 2cat/4wks

# %%
precip1.two_week_spei_plot('precip 1 rolling',['gamma', 'pearson'],2002, 2024)
precip1.four_week_spei_plot('precip 1 rolling',['gamma', 'pearson'],2002, 2024)
precip1.two_week_spei_plot('precip 1 rolling',['gamma', 'pearson'],2016, 2017)
precip1.four_week_spei_plot('precip 1 rolling',['gamma', 'pearson'],2016, 2017)

# %% [markdown]
# Precip1 Combined Onsets
# - 2cat/2wk and 2cat/4wk

# %%
precip1_two_wk = precip1.display_two_wk_onsets('precip 1 rolling',['gamma','pearson'])
precip1_four_wk = precip1.display_four_wk_onsets('precip 1 rolling',['gamma','pearson'])

# %% [markdown]
# Precip2 Graphs:
# - Total years: 2002 - 2024
#     - 2cat/2wks and 2cat/4wks
# - 2016
#     -  2cat/2wks and 2cat/4wks

# %%
precip2.two_week_spei_plot('precip 2 rolling',['gamma', 'pearson'],2002, 2024)
precip2.four_week_spei_plot('precip 2 rolling',['gamma', 'pearson'],2002, 2024)
precip2.two_week_spei_plot('precip 2 rolling',['gamma', 'pearson'],2016, 2017)
precip2.four_week_spei_plot('precip 2 rolling',['gamma', 'pearson'],2016, 2017)

# %% [markdown]
# Precip2 Combined Onsets
# - 2cat/2wk and 2cat/4wk

# %%
precip2_two_wk = precip2.display_two_wk_onsets('precip 2 rolling',['gamma','pearson'])
precip2_four_wk = precip2.display_four_wk_onsets('precip 2 rolling',['gamma','pearson'])

# %% [markdown]
# Precip4 Graphs:
# - Total years: 2002 - 2024
#     - 2cat/2wks and 2cat/4wks
# - 2016
#     -  2cat/2wks and 2cat/4wks

# %%
precip4.two_week_spei_plot('precip 4 rolling',['gamma', 'pearson'],2002, 2024)
precip4.four_week_spei_plot('precip 4 rolling',['gamma', 'pearson'],2002, 2024)
precip4.two_week_spei_plot('precip 4 rolling',['gamma', 'pearson'],2016, 2017)
precip4.four_week_spei_plot('precip 4 rolling',['gamma', 'pearson'],2016, 2017)

# %% [markdown]
# Precip4 Combined Onsets
# - 2cat/2wk and 2cat/4wk

# %%
precip4_two_wk = precip4.display_two_wk_onsets('precip 4 rolling',['gamma','pearson'])
precip4_four_wk = precip4.display_four_wk_onsets('precip 4 rolling',['gamma','pearson'])

# %%
# Filtered to onsets must be found by all distributions being used
required_functions_pet = {'gamma', 'pearson', 'normal'}
pet1_two_wk_filtered = pet1_two_wk[pet1_two_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_pet)].reset_index(drop =True)
pet1_four_wk_filtered = pet1_four_wk[pet1_four_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_pet)].reset_index(drop =True)
pet2_two_wk_filtered = pet2_two_wk[pet2_two_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_pet)].reset_index(drop =True)
pet2_four_wk_filtered = pet2_four_wk[pet2_four_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_pet)].reset_index(drop =True)
pet4_two_wk_filtered = pet4_two_wk[pet4_two_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_pet)].reset_index(drop =True)
pet4_four_wk_filtered = pet4_four_wk[pet4_four_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_pet)].reset_index(drop =True)

required_functions_precip = {'gamma', 'pearson'}
precip1_two_wk_filtered = precip1_two_wk[precip1_two_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_precip)].reset_index(drop =True)
precip1_four_wk_filtered = precip1_four_wk[precip1_four_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_precip)].reset_index(drop =True)
precip2_two_wk_filtered = precip2_two_wk[precip2_two_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_precip)].reset_index(drop =True)
precip2_four_wk_filtered = precip2_four_wk[precip2_four_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_precip)].reset_index(drop =True)
precip4_two_wk_filtered = precip4_two_wk[precip4_two_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_precip)].reset_index(drop =True)
precip4_four_wk_filtered = precip4_four_wk[precip4_four_wk['function'].apply(lambda x: set(map(str.strip, x.split(','))) == required_functions_precip)].reset_index(drop =True)

# %%
# 1 week rolling 2cat/2wk
pet1_two_wk_filtered['parameter'] = 'pet'
pet1_two_wk_filtered[['onset_date','parameter']]
precip1_two_wk_filtered['parameter'] = 'precip'
precip1_two_wk_filtered[['onset_date','parameter']]
vwc_two_wk['parameter'] = 'vwc'
vwc_two_wk[['onset_date','parameter']]
df = pd.concat([pet1_two_wk_filtered, precip1_two_wk_filtered, vwc_two_wk ])
grouped = df.groupby('onset_date')['parameter'].agg(lambda x: ', '.join(sorted(set(x)))).reset_index()
# plt.scatter(grouped['onset_date'],grouped['parameter'])
# required_parameters = {'precip','pet','vwc'}
# grouped_filtered = grouped[grouped['parameter'].apply(lambda x: set(map(str.strip, x.split(','))) == required_parameters)].reset_index(drop =True)
# grouped_filtered
grouped.head(25)
# Out:
#    onset_date parameter
# 0  2002-05-14    precip
# 1  2002-07-23       pet
# 2  2002-07-30    precip
# 3  2003-04-08       vwc
# 4  2003-06-17    precip
# 5  2003-09-30       pet
# 6  2004-09-28       vwc
# 7  2005-04-12       vwc
# 8  2005-05-31       pet
# 9  2005-07-12       pet
# 10 2006-03-21  pet, vwc
# 11 2006-04-11       vwc
# 12 2006-06-06       pet
# 13 2006-07-18       pet
# 14 2006-09-26       pet
# 15 2006-10-31       vwc
# 16 2007-05-01       pet
# 17 2007-06-05    precip
# 18 2007-07-24       pet
# 19 2007-09-18       vwc
# 20 2007-10-09       pet
# 21 2008-03-11    precip
# 22 2008-04-08       pet
# 23 2008-04-15       vwc
# 24 2008-04-29    precip

# %%
# 2 week rolling 2cat/2wk
pet2_two_wk_filtered['parameter'] = 'pet'
pet2_two_wk_filtered[['onset_date','parameter']]
precip2_two_wk_filtered['parameter'] = 'precip'
precip2_two_wk_filtered[['onset_date','parameter']]
vwc_two_wk['parameter'] = 'vwc'
vwc_two_wk[['onset_date','parameter']]
df = pd.concat([pet2_two_wk_filtered, precip2_two_wk_filtered, vwc_two_wk ])
grouped = df.groupby('onset_date')['parameter'].agg(lambda x: ', '.join(sorted(set(x)))).reset_index()
grouped_2016 = grouped[grouped['onset_date'].dt.year == 2016]
grouped_2016
# required_parameters = {'precip','pet','vwc'}
# grouped_filtered = grouped[grouped['parameter'].apply(lambda x: set(map(str.strip, x.split(','))) == required_parameters)].reset_index(drop =True)
# grouped_filtered
# Out:
#    onset_date    parameter
# 40 2016-04-12          pet
# 41 2016-05-17       precip
# 42 2016-06-07       precip
# 43 2016-06-14          pet
# 44 2016-07-26       precip
# 45 2016-08-23  pet, precip
# 46 2016-10-04          pet

# %%
# 4 week rolling 2cat/2wk
pet4_two_wk_filtered['parameter'] = 'pet'
pet4_two_wk_filtered[['onset_date','parameter']]
precip4_two_wk_filtered['parameter'] = 'precip'
precip4_two_wk_filtered[['onset_date','parameter']]
vwc_two_wk['parameter'] = 'vwc'
vwc_two_wk[['onset_date','parameter']]
df = pd.concat([pet4_two_wk_filtered, precip4_two_wk_filtered, vwc_two_wk ])
grouped = df.groupby('onset_date')['parameter'].agg(lambda x: ', '.join(sorted(set(x)))).reset_index()
required_parameters = {'precip','pet','vwc'}
grouped_filtered = grouped[grouped['parameter'].apply(lambda x: set(map(str.strip, x.split(','))) == required_parameters)].reset_index(drop =True)
grouped_filtered
# Out:
# Empty DataFrame
# Columns: [onset_date, parameter]
# Index: []

# %%
# 1 week rolling 2cat/4wk
pet1_four_wk_filtered['parameter'] = 'pet'
pet1_four_wk_filtered[['onset_date','parameter']]
precip1_four_wk_filtered['parameter'] = 'precip'
precip1_four_wk_filtered[['onset_date','parameter']]
vwc_four_wk['parameter'] = 'vwc'
vwc_four_wk[['onset_date','parameter']]
df = pd.concat([pet1_four_wk_filtered, precip1_four_wk_filtered, vwc_four_wk ])
grouped = df.groupby('onset_date')['parameter'].agg(lambda x: ', '.join(sorted(set(x)))).reset_index()
required_parameters = {'precip','pet','vwc'}
grouped_filtered = grouped[grouped['parameter'].apply(lambda x: set(map(str.strip, x.split(','))) == required_parameters)].reset_index(drop =True)
grouped_filtered
# Out:
# Empty DataFrame
# Columns: [onset_date, parameter]
# Index: []

# %%
# 2 week rolling 2cat/4wk
pet2_four_wk_filtered['parameter'] = 'pet'
pet2_four_wk_filtered[['onset_date','parameter']]
precip2_four_wk_filtered['parameter'] = 'precip'
precip2_four_wk_filtered[['onset_date','parameter']]
vwc_four_wk['parameter'] = 'vwc'
vwc_four_wk[['onset_date','parameter']]
df = pd.concat([pet2_four_wk_filtered, precip2_four_wk_filtered, vwc_four_wk ])
grouped = df.groupby('onset_date')['parameter'].agg(lambda x: ', '.join(sorted(set(x)))).reset_index()
required_parameters = {'precip','pet','vwc'}
grouped_filtered = grouped[grouped['parameter'].apply(lambda x: set(map(str.strip, x.split(','))) == required_parameters)].reset_index(drop =True)
grouped_filtered
# Out:
# Empty DataFrame
# Columns: [onset_date, parameter]
# Index: []

# %%
# 4 week rolling 2cat/4wk
pet4_four_wk_filtered['parameter'] = 'pet'
pet4_four_wk_filtered[['onset_date','parameter']]
precip4_four_wk_filtered['parameter'] = 'precip'
precip4_four_wk_filtered[['onset_date','parameter']]
vwc_four_wk['parameter'] = 'vwc'
vwc_four_wk[['onset_date','parameter']]
df = pd.concat([pet4_four_wk_filtered, precip4_four_wk_filtered, vwc_four_wk ])
grouped = df.groupby('onset_date')['parameter'].agg(lambda x: ', '.join(sorted(set(x)))).reset_index()
required_parameters = {'precip','pet','vwc'}
grouped_filtered = grouped[grouped['parameter'].apply(lambda x: set(map(str.strip, x.split(','))) == required_parameters)].reset_index(drop =True)
grouped_filtered
# Out:
# Empty DataFrame
# Columns: [onset_date, parameter]
# Index: []
